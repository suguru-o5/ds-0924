# %% [markdown]
# # Analyzing Student Performance Data with BigQuery

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### Objective
# The objective of this project is to analyze students' performance using BigQuery.
# The focus is on understanding causes which influence students' performance, visualizing them, and suggesting how we can help them improve their performance.

# %% [markdown]
# ### Dataset used
# - Student Performance Dataset:
# Obtained in a survey of students' math course in secondary school.
# Contains variable features such as age, gender, grades, etc.
# The whole details are here in the link:
# https://archive.ics.uci.edu/dataset/320/student+performance

# %% [markdown]
# ## 2. Data Exploration

# %% [markdown]
# ### Key Findings:
# Upon exploring the dataset and just with basic SQLs, I found that there seems to be no specific relationship between gender and the grade each student got.

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ## 4. Data Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("csvs/studytime_and_grade.csv")
df = pd.DataFrame(data)

plt.bar(df['studytime'], df['avg_grade'], color='blue')
plt.xlabel('Study Time (1: very low, 4: very high)')
plt.ylabel('Average Grade')
plt.title('Study Time vs. Average Grade')
plt.show()

# %%
import numpy as np

data = pd.read_csv("csvs/absence_and_grade.csv")
df = pd.DataFrame(data)

plt.scatter(df["absences"], df["avg_grade"], color="red")
x = df["absences"]
y = df["avg_grade"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color="blue", label="Trend Line (Linear)")

plt.xlabel("Absences")
plt.ylabel("Average Grade")
plt.title("Absences vs. Average Grade")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("csvs/parents_education_and_grade.csv")
df = pd.DataFrame(data)

pivot_table = df.pivot(index='Medu', columns='Fedu', values='avg_grade')

plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, fmt=".1f", cmap="coolwarm", cbar_kws={'label': 'Avg Grade'})
plt.title("Parental Education vs. Average Grade")
plt.xlabel("Father's Education Level (Fedu)")
plt.ylabel("Mother's Education Level (Medu)")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## 5. Data Visualization

# %% [markdown]
# ## 6. Conclusion
